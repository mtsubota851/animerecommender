# %% [markdown]
# # Importing Libraries

# %%
import os
import numpy as np
import pandas as pd

import warnings

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

warnings.filterwarnings("always")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Importing Data

# %%
anime_complete_df = pd.read_csv(r'C:\Users\tsubo\Data Analytics\Anime Recommendations\Data\anime2.csv')
anime_synop_df = pd.read_csv(r'C:\Users\tsubo\Data Analytics\Anime Recommendations\Data\anime_with_synopsis.csv')

# %%
anime_synop_df.head(2)
# Out:
#    MAL_ID                             Name Score  \
# 0       1                     Cowboy Bebop  8.78
# 1       5  Cowboy Bebop: Tengoku no Tobira  8.39
#
#                                             Genres  \
# 0  Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1            Action, Drama, Mystery, Sci-Fi, Space
#
#                                            sypnopsis
# 0  In the year 2071, humanity has colonized sever...
# 1  other day, another bounty—such is the life of ...

# %%
anime_synop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16214 entries, 0 to 16213
# Data columns (total 5 columns):
# MAL_ID       16214 non-null int64
# Name         16214 non-null object
# Score        16214 non-null object
# Genres       16214 non-null object
# sypnopsis    16206 non-null object
# dtypes: int64(1), object(4)
# memory usage: 633.4+ KB

# %%
anime_synop_df = anime_synop_df[['MAL_ID', 'Name', 'Genres', 'sypnopsis']]

# %%
anime_df = anime_synop_df.join(anime_complete_df, on='MAL_ID', rsuffix='r')

# %%
anime_df = anime_df[['Name', 'Genres', 'sypnopsis', 'Type']]

# %%
anime_df.columns = ['Name', 'Genres', 'Synopsis', 'Type']

# %%
anime_df
# Out:
#                                                     Name  \
# 0                                           Cowboy Bebop
# 1                        Cowboy Bebop: Tengoku no Tobira
# 2                                                 Trigun
# 3                                     Witch Hunter Robin
# 4                                         Bouken Ou Beet
# 5                                           Eyeshield 21
# 6                                   Hachimitsu to Clover
# 7                             Hungry Heart: Wild Striker
# 8                                 Initial D Fourth Stage
# 9                                                Monster
# 10                                                Naruto
# 11                                             One Piece
# 12                                   Tennis no Ouji-sama
# 13                                      Ring ni Kakero 1
# 14                                         School Rumble
# 15                                             Sunabouzu
# 16                                            Texhnolyze
# 17                                         Trinity Blood
# 18                                      Yakitate!! Japan
# 19                                                Zipang
# 20                               Neon Genesis Evangelion
# 21              Neon Genesis Evangelion: Death & Rebirth
# 22        Neon Genesis Evangelion: The End of Evangelion
# 23                                  Kenpuu Denki Berserk
# 24                                      Koukaku Kidoutai
# 25     Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...
# 26               Rurouni Kenshin: Meiji Kenkaku Romantan
# 27     Rurouni Kenshin: Meiji Kenkaku Romantan - Ishi...
# 28                                                 Akira
# 29                                           .hack//Sign
# ...                                                  ...
# 16184                                     Youkai Watch ♪
# 16185                      Wo Shi Da Shenxian 2nd Season
# 16186                             Fei Ren Zai 4th Season
# 16187           Mahouka Koukou no Rettousei: Tsuioku-hen
# 16188                                       Mazica Party
# 16189                            Totsukuni no Shoujo OVA
# 16190                                            Re-Main
# 16191                      Chocomatsu-san: White Day-hen
# 16192                               Aria the Benedizione
# 16193                     Hataraku Maou-sama! 2nd Season
# 16194                                      Sabikui Bisco
# 16195  Shijou Saikyou no Daimaou, Murabito A ni Tense...
# 16196  Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 16197  Maou Gakuin no Futekigousha: Shijou Saikyou no...
# 16198                             Akuma-kun (Shin Anime)
# 16199                     Kitarou Tanjou: Gegege no Nazo
# 16200                            The Sun, Moon and Stars
# 16201  Mahoutsukai no Yome: Nishi no Shounen to Seira...
# 16202                      Eiyuu Densetsu: Sen no Kiseki
# 16203                                       Shikaru Neko
# 16204                                SK∞: Crazy Rock Jam
# 16205                                      Kyoukai Senki
# 16206                                   D_Cide Traumerei
# 16207                        Tsuki to Laika to Nosferatu
# 16208                        Wan Jie Shen Zhu 3rd Season
# 16209                    Daomu Biji Zhi Qinling Shen Shu
# 16210                                       Mieruko-chan
# 16211                    Higurashi no Naku Koro ni Sotsu
# 16212                        Yama no Susume: Next Summit
# 16213                                      Scarlet Nexus
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1
# 3      ches are individuals with special powers like ...     TV
# 4      It is the dark century and the people are suff...     TV
# 5      Sena is like any other shy kid starting high s...     TV
# 6      Yuuta Takemoto, a sophomore at an arts college...     TV
# 7      Kyosuke Kano has lived under the shadow of his...     TV
# 8      Takumi Fujiwara finally joins Ryousuke and Kei...     TV
# 9      Dr. Kenzou Tenma, an elite neurosurgeon recent...     TV
# 10     oments prior to Naruto Uzumaki's birth, a huge...     TV
# 11     Gol D. Roger was known as the "Pirate King," t...  Movie
# 12     The world of tennis is harsh and highly compet...  Movie
# 13     In order to fulfill their dead father's wish, ...     TV
# 14     Just the words "I love you," and everything ch...  Movie
# 15     The Great Kanto Desert, a sweltering wasteland...    OVA
# 16     Texhnolyze takes place in the city of Lux, a m...     TV
# 17     Following Armageddon, an apocalyptic war, mank...  Movie
# 18     hile countries such as France, England, and Ge...  Movie
# 19     ai, an improved Kongou-class Aegis guided miss...     TV
# 20     In the year 2015, the world stands on the brin...    OVA
# 21     In the year 2015, more than a decade has passe...     TV
# 22     h the final Angel vanquished, Nerv has one las...    OVA
# 23     Born from the corpse of his mother, a young me...     TV
# 24     In the year 2029, Niihama City has become a te...     TV
# 25     hen mankind's savagery surpasses his fear of d...     TV
# 26     In the final years of the Bakumatsu era lived ...     TV
# 27     The war against the Tokugawa Shogunate ended y...     TV
# 28     Japan, 1988. An explosion caused by a young bo...     TV
# 29     oung wavemaster, only known by the alias of Ts...     TV
# ...                                                  ...    ...
# 16184  The new show will feature unique and returning...    NaN
# 16185             Second season of Wo Shi Da Shen Shan .    NaN
# 16186                     Fourth season of Fei Ren Zai .    NaN
# 16187  ooking at Miyuki and Tatsuya now, it might be ...    NaN
# 16188  The franchise's story centers on wizards who g...    NaN
# 16189  OVA bundled with the special edition of the ma...    NaN
# 16190  The story centers on Minato Kiyoumizu, a boy w...    NaN
# 16191  Original specials aired exclusively on pay-per...    NaN
# 16192  The third and final installment in the Ao no C...    NaN
# 16193               Second season of Hataraku Maou-sama!    NaN
# 16194  plague-like wind blows across the arid, sandy ...    NaN
# 16195  s the most powerful entity of all time, the De...    NaN
# 16196  Second season of Maou Gakuin no Futekigousha: ...    NaN
# 16197  Second half of Maou Gakuin no Futekigousha: Sh...    NaN
# 16198  hen Mr. Satou, a company employee at the world...    NaN
# 16199  No synopsis information has been added to this...    NaN
# 16200  usic video for Hoshimi Production's fourth dig...    NaN
# 16201  The story takes place shortly before Cartaphil...    NaN
# 16202  Eiyuu Densetsu: Sen no Kiseki centers around R...    NaN
# 16203  No synopsis information has been added to this...    NaN
# 16204               cap of the first 9 episodes of SK∞ .    NaN
# 16205  In the year 2061 AD, Japan has lost its sovere...    NaN
# 16206  The stage is Shibuya. When Ryuuhei Oda was in ...    NaN
# 16207  The first astronaut in human history was a vam...    NaN
# 16208  No synopsis information has been added to this...    NaN
# 16209  No synopsis information has been added to this...    NaN
# 16210  ko is a typical high school student whose life...    NaN
# 16211          Sequel to Higurashi no Naku Koro ni Gou .    NaN
# 16212                          New Yama no Susume anime.    NaN
# 16213  Solar calendar year 2020: grotesque organisms ...    NaN
#
# [16214 rows x 4 columns]

# %% [markdown]
# # Anime Missing Values

# %%
anime_df.isnull().sum().sort_values(ascending=False)
# Out:
# Type        9436
# Synopsis       8
# Genres         0
# Name           0
# dtype: int64

# %%
print(anime_df['Synopsis'].mode()[0])
print(anime_df['Type'].mode()[0])
# Out:
# No synopsis information has been added to this title. Help improve our database by adding a synopsis here .
# TV

# %% [markdown]
# Seems like the default message for no synopsis is 'No synopsis information has been added to this title.
# Help improve our database by adding a synopsis here .'.
# We will replace null values in Synopsis with this. For type, we fill in with TV.

# %%
anime_df['Synopsis'] = anime_df['Synopsis'].fillna(
    anime_df['Synopsis'].dropna().mode().values[0]
)
anime_df['Type'] = anime_df['Type'].fillna(
    anime_df['Type'].dropna().mode().values[0]
)

# %% [markdown]
# Verify that we removed all nan values

# %%
anime_df.isnull().sum()
# Out:
# Name        0
# Genres      0
# Synopsis    0
# Type        0
# dtype: int64

# %% [markdown]
# Only care about animes, so type being TV. Others can be dropped

# %%
anime_df = anime_df[anime_df['Type']=='TV']

# %%
anime_df.drop('Type', axis=1, inplace=True)

# %% [markdown]
# # Building the recommender
# We will be using name and genre of each anime. We will use Tf-idf on the names of anime and find the count frequency on the genres of anime. Then, we will use cosine similarity to compute the similarities of the two frequency matrices. Finally, we use the average of the two similarity scores per anime to find recommendations.

# %%
indices = pd.Series(anime_df.index, index = anime_df['Name'])

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf2 = TfidfVectorizer(stop_words='english')
count = CountVectorizer(stop_words='english')

# %%
tfidf_matrix = tfidf.fit_transform(anime_df['Name'])
count_matrix = count.fit_transform(anime_df['Genres'])
tfidf2_matrix = tfidf2.fit_transform(anime_df['Synopsis'])

# %%
name_similarity = cosine_similarity(tfidf_matrix)
genre_similarity = cosine_similarity(count_matrix)
synopsis_similarity = cosine_similarity(tfidf2_matrix)

# %% [markdown]
# # Recommendations

# %%
def get_recommendations(anime):
    i = indices[anime]
    
    name_score = list(enumerate(name_similarity[i]))
    genre_score = list(enumerate(genre_similarity[i]))
    synopsis_score = list(enumerate(synopsis_similarity[i]))
    
    name_score = sorted(name_score, key = lambda x: x[0])
    genre_score = sorted(genre_score, key = lambda x: x[0])
    synopsis_score = sorted(synopsis_score, key = lambda x: x[0])
    
    combined_score = [(i, (sc_1 + sc_2 + sc_3) / 3) for (i, sc_1), (_, sc_2), (_, sc_3) in zip(name_score, genre_score, synopsis_score)]
    
    combined_score = sorted(combined_score, key = lambda x: x[1], reverse = True)
    
    anime_ids = [i[0] for i in combined_score[1:11]]
    
    anime_recs = []
    
    index = 0
    while len(anime_recs) != 10:
        anime_id = combined_score[1:][index][0]
        index += 1
        if anime in indices.iloc[[anime_id]].index[0]:
            continue
        else:
            anime_recs.append(indices.iloc[[anime_id]].index[0])
    
    
    print(f'If you liked {anime}, you should try:')
    for i, v in list(enumerate(anime_recs)):
        print(f'{i + 1}. {v}')

# %%
get_recommendations('Samurai Champloo')
# Out:
# If you liked Samurai Champloo, you should try:
# 1. Hellsing Ultimate
# 2. Hellsing: The Dawn
# 3. Hellsing: Digest for Freaks
# 4. Dance in the Vampire Bund: Special Edition
# 5. Kizumonogatari II: Nekketsu-hen
# 6. Ajin Part 1: Shoudou
# 7. Ajin Part 2: Shoutotsu
# 8. Ajin Part 3: Shougeki
# 9. Ajin
# 10. Bloodivores

# %%
path = r'C:\Users\tsubo\Data Analytics\Anime Recommendations\Data'

# %%
anime_df.to_csv(os.path.join(path, 'anime_df.csv'))
